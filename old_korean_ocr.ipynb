# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import json
import cv2
from tqdm import tqdm
from pprint import pprint

from google.colab.patches import cv2_imshow

# %%
# !git clone https://github.com/HyeJuSeon/deep-text-recognition-benchmark
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 518, done.
# remote: Total 518 (delta 0), reused 0 (delta 0), pack-reused 518
# Receiving objects: 100% (518/518), 3.08 MiB | 10.77 MiB/s, done.
# Resolving deltas: 100% (315/315), done.

# %%
# %cd deep-text-recognition-benchmark
# Out:
# /content/deep-text-recognition-benchmark

# %%
# !cp -r /content/gdrive/MyDrive/old_korean_ocr/data_lmdb/test /content/deep-text-recognition-benchmark/data_lmdb

# %% [markdown]
# ㅇ

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 train.py \
    --train_data data_lmdb/train \
    --valid_data data_lmdb/val \
	--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
	--data_filtering_off \
    --workers 1 \
    --batch_size 100 \
    --valInterval 100 \
    --lr 1 \
    --num_iter 5000
# Out:
# --------------------------------------------------------------------------------
# dataset_root: data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 1704655
# num total samples of /: 1704655 x 1.0 (total_data_usage_ratio) = 1704655
# num samples of / per batch: 100 x 1.0 (batch_ratio) = 100
# --------------------------------------------------------------------------------
# Total_batch_size: 100 = 100
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/val	 dataset: /
# sub-directory:	/.	 num samples: 515721
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 8817 25 TPS ResNet BiLSTM CTC
# ...

# %%
# !cp -r /content/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111 /content/gdrive/MyDrive/old_korean_ocr

# %% [markdown]
# - evaluation

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
--image_folder /content/gdrive/MyDrive/old_korean_ocr/test \
--saved_model /content/gdrive/MyDrive/old_korean_ocr/models/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_77.png	슈                        	0.3709
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_78.png	심                        	0.8535
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_79.png	이                        	0.9936
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_80.png	뇨                        	0.1087
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_81.png	듯                        	0.9387
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_82.png	난                        	0.4771
# /content/gdrive/MyDrive/old_korean_ocr/test/목판본_001_문학류_춘향전_01_083_83.png	것                        	0.6200
# ...

# %%
# !cp /content/deep-text-recognition-benchmark/log_demo_result.txt /content/gdrive/MyDrive/old_korean_ocr/log_eval_result.txt

# %%
# !cp -r /content/gdrive/MyDrive/old_korean_ocr/unsharp_data_lmdb /content/deep-text-recognition-benchmark/

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 train.py \
    --train_data unsharp_data_lmdb/train \
    --valid_data unsharp_data_lmdb/val \
	--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction CTC \
	--data_filtering_off \
    --workers 1 \
    --batch_size 100 \
    --valInterval 100 \
    --lr 1 \
    --num_iter 5000
# Out:
# --------------------------------------------------------------------------------
# dataset_root: unsharp_data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    unsharp_data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 1654605
# num total samples of /: 1654605 x 1.0 (total_data_usage_ratio) = 1654605
# num samples of / per batch: 100 x 1.0 (batch_ratio) = 100
# --------------------------------------------------------------------------------
# Total_batch_size: 100 = 100
# --------------------------------------------------------------------------------
# dataset_root:    unsharp_data_lmdb/val	 dataset: /
# sub-directory:	/.	 num samples: 515721
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 8817 25 TPS ResNet BiLSTM CTC
# ...

# %%
# !cp -r /content/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-CTC-Seed1111 /content/gdrive/MyDrive/old_korean_ocr
